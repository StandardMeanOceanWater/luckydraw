# %% [markdown]
# <a href="https://colab.research.google.com/github/StandardMeanOceanWater/luckydraw/blob/main/%E6%8A%BD%E7%B1%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

def classroom_lottery():
    print("班級抽籤程式")

    while True:
        try:
            num_students = int(input("請輸入全班總人數 (例如 30): "))
            break
        except ValueError:
            print("輸入錯誤，請輸入數字！")

    # 建立座號清單 (1 到 num_students)
    students = list(range(1, num_students + 1))

    print(f"\n已建立 1 到 {num_students} 號的籤筒。")
    print("--------------------------------")

    while len(students) > 0:
        input(f"按下 Enter 鍵來抽籤 (目前剩餘 {len(students)} 人)...")

        # 營造一點緊張感
        print("抽籤中...", end="\r")
        time.sleep(0.5)

        # 隨機選擇並從清單中移除 (取出不放回)
        winner = random.choice(students)
        students.remove(winner)

        print(f"抽中座號：【 {winner} 】號")
        print("--------------------------------")

    print("全班都抽完囉！程式結束。")

if __name__ == "__main__":
    classroom_lottery()
# Out:
# --- 班級抽籤程式 (指令版) ---
#
# 已建立 1 到 30 號的籤筒。
# --------------------------------
# 🎉 抽中座號：【 15 】號
# --------------------------------
